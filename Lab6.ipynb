# %%
import tensorflow as tf
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776243688.727962    7966 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Character Level Tokenization

from tokenizers import ByteLevelBPETokenizer

tokenizer = ByteLevelBPETokenizer()
text='The quick brown fox jumps over the lazy dog'
tokenizer.train_from_iterator([text])
print(tokenizer.encode(text).tokens)
# Out:
# ['T', 'he', 'Ġ', 'q', 'u', 'i', 'c', 'k', 'Ġ', 'b', 'r', 'o', 'w', 'n', 'Ġ', 'f', 'o', 'x', 'Ġ', 'j', 'u', 'm', 'p', 's', 'Ġ', 'o', 'v', 'e', 'r', 'Ġ', 't', 'he', 'Ġ', 'l', 'a', 'z', 'y', 'Ġ', 'd', 'o', 'g']

# %%
# Word Level Tokenization

text="Hello, how are you? i am playing with tokenizers"
print(text.split())
# Out:
# ['Hello,', 'how', 'are', 'you?', 'i', 'am', 'playing', 'with', 'tokenizers']

# %%
# Sub-Word Level Tokeninzation

from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
text = "Hello, how are you? i am playing with tokenizers"
token = tokenizer.tokenize(text)
print(encoded_input)
# Out:
# /home/assassins/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ['hello', ',', 'how', 'are', 'you', '?', 'i', 'am', 'playing', 'with', 'token', '##izer', '##s']

# %%
encoder=tokenizer.encode(text)
print(encoder)
# Out:
# [101, 7592, 1010, 2129, 2024, 2017, 1029, 1045, 2572, 2652, 2007, 19204, 17629, 2015, 102]
